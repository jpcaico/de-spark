# %%
from pyspark.sql import SparkSession
from pyspark.sql import Row
from pyspark.sql import functions as func

# %%
spark = SparkSession.builder.appName("friendsByAge").getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/05/02 18:16:35 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 25/05/02 18:16:36 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
# 25/05/02 18:16:36 WARN Utils: Service 'SparkUI' could not bind on port 4041. Attempting port 4042.
# 25/05/02 18:16:36 WARN Utils: Service 'SparkUI' could not bind on port 4042. Attempting port 4043.
# 25/05/02 18:16:36 WARN Utils: Service 'SparkUI' could not bind on port 4043. Attempting port 4044.
# 25/05/02 18:16:36 WARN Utils: Service 'SparkUI' could not bind on port 4044. Attempting port 4045.

# %%
friends = spark.read.option("header","true").option("inferSchema","true").csv("/opt/spark/data/fakefriends-header.csv")

# %%
friends.show(10)
# Out:
# +------+--------+---+-------+
# |userID|    name|age|friends|
# +------+--------+---+-------+
# |     0|    Will| 33|    385|
# |     1|Jean-Luc| 26|      2|
# |     2|    Hugh| 55|    221|
# |     3|  Deanna| 40|    465|
# |     4|   Quark| 68|     21|
# |     5|  Weyoun| 59|    318|
# |     6|  Gowron| 37|    220|
# |     7|    Will| 54|    307|
# |     8|  Jadzia| 38|    380|
# |     9|    Hugh| 27|    181|
# +------+--------+---+-------+
# only showing top 10 rows

# %%
friends.select("age","friends").groupBy("age").avg("friends").sort("age").show()
# Out:
# +---+------------------+
# |age|      avg(friends)|
# +---+------------------+
# | 18|           343.375|
# | 19|213.27272727272728|
# | 20|             165.0|
# | 21|           350.875|
# | 22|206.42857142857142|
# | 23|             246.3|
# | 24|             233.8|
# | 25|197.45454545454547|
# | 26|242.05882352941177|
# | 27|           228.125|
# | 28|             209.1|
# | 29|215.91666666666666|
# | 30| 235.8181818181818|
# | 31|            267.25|
# | 32| 207.9090909090909|
# | 33| 325.3333333333333|
# | 34|             245.5|
# | 35|           211.625|
# | 36|             246.6|
# | 37|249.33333333333334|
# +---+------------------+
# only showing top 20 rows

# %%
friends.select("age","friends").groupBy("age").agg(func.round(func.avg("friends"), 2).alias("friends_avg")).sort("age").show()
# Out:
# +---+-----------+
# |age|friends_avg|
# +---+-----------+
# | 18|     343.38|
# | 19|     213.27|
# | 20|      165.0|
# | 21|     350.88|
# | 22|     206.43|
# | 23|      246.3|
# | 24|      233.8|
# | 25|     197.45|
# | 26|     242.06|
# | 27|     228.13|
# | 28|      209.1|
# | 29|     215.92|
# | 30|     235.82|
# | 31|     267.25|
# | 32|     207.91|
# | 33|     325.33|
# | 34|      245.5|
# | 35|     211.63|
# | 36|      246.6|
# | 37|     249.33|
# +---+-----------+
# only showing top 20 rows
